# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
path = "C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/" # erzeugt Warning bei !ls {path}
path_cyg = "/cygdrive/c/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/"

# %%
# Image.open("/cygdrive/c/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/") funktioniert nicht
img = np.array(Image.open('C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/cats/cat.33.jpg'))
plt.imshow(img)

# %%
path
# Out:
# 'C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/'

# %%
path + str('cats/')
# Out:
# 'C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/cats/'

# %%
# !ls {path_cyg}
# Out:
# cats
# dogs

# %%
# files muss mit path_cyg erzeugt werden, da sonst der path cygwin warning: enthält (Siehe filez, Zeile unten)
files = !ls {path_cyg}cats
files
# Out:
# ['cat.1.jpg', 'cat.33.jpg', 'cat.42.jpg']

# %%
# So gehts nicht
filez = !ls {path}cats
filez
# Out:
# ['cygwin warning:',
#  '  MS-DOS style path detected: C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/cats',
#  '  Preferred POSIX equivalent is: /cygdrive/c/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/cats',
#  '  CYGWIN environment variable option "nodosfilewarning" turns off this warning.',
#  "  Consult the user's guide for more details about POSIX paths:",
#  '    http://cygwin.com/cygwin-ug-net/using.html#using-pathnames',
#  'cat.1.jpg',
#  'cat.33.jpg',
#  'cat.42.jpg']

# %%
path + 'cats/' + str(files[0])
# Out:
# 'C:/Users/User/Ordnerzugriff_Python/OzP_Image/dogscats/cats/cat.1.jpg'

# %%
example = np.array(Image.open(path + 'cats/' + files[0]))

# %%
plt.imshow(example)

# %%
anzahl_cats = len(files)
for i in range(anzahl_cats):
    plt.figure()
    plt.imshow(np.array(Image.open(path + 'cats/' + files[i])))
    a = str(files[i])
    plt.title(a)
